# %% [markdown]
# ![image.png](attachment:image.png)

# %%
n1 = 5
n2 = 3
sugar = int(input("설탕 무게 : "))

def division(val):
    num_1 = val // 5
    temp = val % 5
    num_2 = temp // 3
    if temp % 3 > 0:
        if val % 3 == 0:
            return val // 3
        else:
            return -1
    else:
        print(num_1)
        print(num_2)
        return num_1 + num_2
division(sugar)
# Out:
# 설탕 무게 : 9
# 3

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def pago(val):
    if val == 1:
        return 1
    elif val == 2:
        return 1
    else:
        return pago(val-1) + pago(val-2)

# %%
pago(10)
# Out:
# 55
